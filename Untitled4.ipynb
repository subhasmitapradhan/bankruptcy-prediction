# %% [markdown]
# <a href="https://colab.research.google.com/github/subhasmitapradhan/bankruptcy-prediction/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('data.csv')
df.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# 4                                           0.522298
#
#     Operating Gross Margin   Realized Sales Gross Margin  \
# 0                 0.601457                      0.601457
# 1                 0.610235                      0.610235
# 2                 0.601450                      0.601364
# 3                 0.583541                      0.583541
# 4                 0.598783                      0.598783
#
#     Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                0.998969                    0.796887
# 1                0.998946                    0.797380
# 2                0.998857                    0.796403
# 3                0.998700                    0.796967
# 4                0.998973                    0.797366
#
#     After-tax net Interest Rate   Non-industry income and expenditure/revenue  \
# 0                      0.808809                                      0.302646
# 1                      0.809301                                      0.303556
# 2                      0.808388                                      0.302035
# 3                      0.808966                                      0.303350
# 4                      0.809304                                      0.303475
#
#    ...   Net Income to Total Assets   Total assets to GNP price  \
# 0  ...                     0.716845                    0.009219
# 1  ...                     0.795297                    0.008323
# 2  ...                     0.774670                    0.040003
# 3  ...                     0.739555                    0.003252
# 4  ...                     0.795016                    0.003878
#
#     No-credit Interval   Gross Profit to Sales  \
# 0             0.622879                0.601453
# 1             0.623652                0.610237
# 2             0.623841                0.601449
# 3             0.622929                0.583538
# 4             0.623521                0.598782
#
#     Net Income to Stockholder's Equity   Liability to Equity  \
# 0                             0.827890              0.290202
# 1                             0.839969              0.283846
# 2                             0.836774              0.290189
# 3                             0.834697              0.281721
# 4                             0.839973              0.278514
#
#     Degree of Financial Leverage (DFL)  \
# 0                             0.026601
# 1                             0.264577
# 2                             0.026555
# 3                             0.026697
# 4                             0.024752
#
#     Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 0                                           0.564050                   1
# 1                                           0.570175                   1
# 2                                           0.563706                   1
# 3                                           0.564663                   1
# 4                                           0.575617                   1
#
#     Equity to Liability
# 0              0.016469
# 1              0.020794
# 2              0.016474
# 3              0.023982
# 4              0.035490
#
# [5 rows x 96 columns]

# %%
df.shape
# Out:
# (6819, 96)

# %%
df.dtypes.value_counts()
# Out:
# float64    93
# int64       3
# dtype: int64

# %%
# Lets see which are the variables with int64 datatype
df.describe(exclude='float64')
# Out:
#          Bankrupt?   Liability-Assets Flag   Net Income Flag
# count  6819.000000             6819.000000            6819.0
# mean      0.032263                0.001173               1.0
# std       0.176710                0.034234               0.0
# min       0.000000                0.000000               1.0
# 25%       0.000000                0.000000               1.0
# 50%       0.000000                0.000000               1.0
# 75%       0.000000                0.000000               1.0
# max       1.000000                1.000000               1.0

# %% [markdown]
# **Check Missing Values**

# %%
missing= [feature for feature in df.columns if df[feature].isnull().sum()]
missing
# There are no missing values therefore we can proceed
# Out:
# []

# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# 1) Check for Class Imbalance

# %%
print('Financially Stable :',round(df['Bankrupt?'].value_counts()[0]/len(df)*100,2),'%')
print('Financially Unstable :',round(df['Bankrupt?'].value_counts()[1]/len(df)*100,2),'%')
# Out:
# Financially Stable : 96.77 %
# Financially Unstable : 3.23 %

# %% [markdown]
# It can be seen that the class imbalance is too high therefore its necessary to perform under or over sampling techniques

# %% [markdown]
# **Data Preprocessing**

# %% [markdown]
# 1) Feature Scaling

# %%
# For Artificial Neural Network(ANN) its preferable to scale the features in the range between 0-1
from sklearn.preprocessing import Normalizer
normal= Normalizer()

# %%
# Some features have values more than 2 while most of them range between 0-1
cols_for_scale = df.max()[df.max()>1]
cols_for_scale
# Out:
#  Operating Expense Rate                   9.990000e+09
#  Research and development expense rate    9.980000e+09
#  Interest-bearing debt interest rate      9.900000e+08
#  Revenue Per Share (Yuan ¥)               3.020000e+09
#  Total Asset Growth Rate                  9.990000e+09
#  Net Value Growth Rate                    9.330000e+09
#  Current Ratio                            2.750000e+09
#  Quick Ratio                              9.230000e+09
#  Total debt/Total net worth               9.940000e+09
#  Accounts Receivable Turnover             9.740000e+09
#  Average Collection Days                  9.730000e+09
#  Inventory Turnover Rate (times)          9.990000e+09
#  Fixed Assets Turnover Frequency          9.990000e+09
#  Revenue per person                       8.810000e+09
#  Allocation rate per person               9.570000e+09
#  Quick Assets/Current Liability           8.820000e+09
#  Cash/Current Liability                   9.650000e+09
#  Inventory/Current Liability              9.910000e+09
#  Long-term Liability to Current Assets    9.540000e+09
#  Current Asset Turnover Rate              1.000000e+10
#  Quick Asset Turnover Rate                1.000000e+10
#  Cash Turnover Rate                       1.000000e+10
#  Fixed Assets to Assets                   8.320000e+09
#  Total assets to GNP price                9.820000e+09
# dtype: float64

# %%
scaled=normal.fit_transform(df[cols_for_scale.keys()])
i=0
for col in cols_for_scale.keys():
  df[col]= scaled[:,i]
  i+=1

# %%
df[cols_for_scale.keys()].describe()
# Out:
#         Operating Expense Rate   Research and development expense rate  \
# count             6.819000e+03                            6.819000e+03
# mean              1.661826e-01                            1.798982e-01
# std               2.686726e-01                            2.439265e-01
# min               0.000000e+00                            0.000000e+00
# 25%               1.519550e-14                            1.374627e-14
# 50%               3.398208e-14                            4.866544e-02
# 75%               3.595572e-01                            3.099536e-01
# max               1.000000e+00                            1.000000e+00
#
#         Interest-bearing debt interest rate   Revenue Per Share (Yuan ¥)  \
# count                          6.819000e+03                 6.819000e+03
# mean                           2.793805e-03                 2.837294e-03
# std                            3.347629e-02                 3.656447e-02
# min                            0.000000e+00                 0.000000e+00
# 25%                            1.739469e-14                 1.512247e-12
# 50%                            3.003037e-14                 2.608393e-12
# 75%                            5.203387e-14                 4.632151e-12
# max                            1.000000e+00                 8.487490e-01
#
#         Total Asset Growth Rate   Net Value Growth Rate   Current Ratio  \
# count               6819.000000            6.819000e+03    6.819000e+03
# mean                   0.521366            2.526750e-04    1.807180e-03
# std                    0.295456            9.261127e-03    2.253940e-02
# min                    0.000000            0.000000e+00    0.000000e+00
# 25%                    0.394648            3.509776e-14    6.475588e-13
# 50%                    0.555354            4.303322e-14    1.008187e-12
# 75%                    0.715952            5.799017e-14    1.793761e-12
# max                    1.000000            6.529784e-01    5.367221e-01
#
#         Quick Ratio   Total debt/Total net worth  \
# count  6.819000e+03                 6.819000e+03
# mean   2.238776e-03                 8.128968e-04
# std    2.882217e-02                 1.890347e-02
# min    0.000000e+00                 0.000000e+00
# 25%    3.979811e-13                 2.913931e-13
# 50%    6.812818e-13                 5.222331e-13
# 75%    1.348215e-12                 9.342875e-13
# max    9.979026e-01                 1.000000e+00
#
#         Accounts Receivable Turnover  ...   Allocation rate per person  \
# count                   6.819000e+03  ...                 6.819000e+03
# mean                    1.571919e-03  ...                 1.245806e-03
# std                     3.106988e-02  ...                 2.713023e-02
# min                     0.000000e+00  ...                 0.000000e+00
# 25%                     6.411360e-14  ...                 3.929599e-13
# 50%                     9.161320e-14  ...                 7.619823e-13
# 75%                     1.542349e-13  ...                 1.544504e-12
# max                     9.920834e-01  ...                 9.990426e-01
#
#         Quick Assets/Current Liability   Cash/Current Liability  \
# count                     6.819000e+03             6.819000e+03
# mean                      1.932987e-03             5.402385e-03
# std                       2.565646e-02             5.238207e-02
# min                       0.000000e+00             0.000000e+00
# 25%                       4.352061e-13             1.791773e-13
# 50%                       7.442508e-13             4.363585e-13
# 75%                       1.423051e-12             1.340645e-12
# max                       7.718045e-01             9.045574e-01
#
#         Inventory/Current Liability   Long-term Liability to Current Assets  \
# count                  6.819000e+03                            6.819000e+03
# mean                   6.385116e-03                            5.054701e-03
# std                    6.060400e-02                            5.057847e-02
# min                    0.000000e+00                            0.000000e+00
# 25%                    2.979310e-13                            0.000000e+00
# 50%                    6.027074e-13                            1.842331e-13
# 75%                    1.131049e-12                            8.563656e-13
# max                    1.000000e+00                            1.000000e+00
#
#         Current Asset Turnover Rate   Quick Asset Turnover Rate  \
# count                  6.819000e+03                6.819000e+03
# mean                   9.047842e-02                1.663581e-01
# std                    2.095006e-01                2.567653e-01
# min                    0.000000e+00                0.000000e+00
# 25%                    1.332994e-14                1.436237e-14
# 50%                    2.170159e-14                2.879315e-14
# 75%                    7.644453e-14                3.958447e-01
# max                    9.948360e-01                1.000000e+00
#
#         Cash Turnover Rate   Fixed Assets to Assets  \
# count         6.819000e+03             6.819000e+03
# mean          2.136371e-01             5.369853e-03
# std           2.511621e-01             6.399606e-02
# min           0.000000e+00             0.000000e+00
# 25%           3.557629e-14             8.655750e-12
# 50%           1.030018e-01             1.995942e-11
# 75%           3.939487e-01             3.598065e-11
# max           1.000000e+00             9.939660e-01
#
#         Total assets to GNP price
# count                6.819000e+03
# mean                 1.864470e-03
# std                  3.355149e-02
# min                  0.000000e+00
# 25%                  9.018238e-14
# 50%                  2.105962e-13
# 75%                  5.595239e-13
# max                  7.900241e-01
#
# [8 rows x 24 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()

# %%
scaled=scale.fit_transform(df[cols_for_scale.keys()])
i=0
for col in cols_for_scale.keys():
  df[col]= scaled[:,i]
  i+=1

# %%
df[cols_for_scale.keys()].describe()
# Out:
#         Operating Expense Rate  ...   Total assets to GNP price
# count             6.819000e+03  ...                6.819000e+03
# mean              1.661826e-01  ...                2.360017e-03
# std               2.686726e-01  ...                4.246894e-02
# min               0.000000e+00  ...                0.000000e+00
# 25%               1.519550e-14  ...                1.141514e-13
# 50%               3.398208e-14  ...                2.665693e-13
# 75%               3.595572e-01  ...                7.082365e-13
# max               1.000000e+00  ...                1.000000e+00
#
# [8 rows x 24 columns]

# %% [markdown]
# 2) Over Sampling the Data

# %%
X,y= df.drop('Bankrupt?',axis=1),df['Bankrupt?']
X.shape,y.shape
# Out:
# ((6819, 95), (6819,))

# %%
smote=SMOTE(sampling_strategy='minority')
X_res,y_res=smote.fit_resample(X,y)

# %%
print(X_res.shape)
print(y_res.shape)
# Out:
# (13198, 95)
# (13198,)

# %%
print(type(X_res))
print(type(y_res))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
X_re=pd.DataFrame(X_res,columns=X.columns)
y_re=pd.DataFrame(y_res,columns=['Bankrupt?'])

# %%
y_re.value_counts().plot(kind='pie',autopct="%.2f")
plt.show()

# %% [markdown]
# 3) Splitting the Data

# %%
x_train,x_test,y_train,y_test = train_test_split(X_re, y_re, test_size=0.3)

# %% [markdown]
# **Model Building**

# %% [markdown]
# 1) ANN

# %%
import tensorflow as tf

# %%
initializer = tf.keras.initializers.HeNormal()
model = keras.Sequential([
    keras.layers.Dense(95,input_shape=(95,),activation='relu',kernel_initializer=initializer),
    keras.layers.Dense(1,activation='sigmoid')
])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=200)
# Out:
# Epoch 1/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7573
# Epoch 2/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.3662 - accuracy: 0.8600
# Epoch 3/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.3224 - accuracy: 0.8743
# Epoch 4/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.3035 - accuracy: 0.8794
# Epoch 5/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2880 - accuracy: 0.8861
# Epoch 6/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2833 - accuracy: 0.8860
# Epoch 7/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2721 - accuracy: 0.8912
# Epoch 8/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2697 - accuracy: 0.8918
# Epoch 9/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2649 - accuracy: 0.8936
# Epoch 10/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2608 - accuracy: 0.8952
# Epoch 11/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2579 - accuracy: 0.8947
# Epoch 12/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2554 - accuracy: 0.8978
# Epoch 13/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2537 - accuracy: 0.8992
# Epoch 14/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2485 - accuracy: 0.8993
# Epoch 15/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2479 - accuracy: 0.9008
# Epoch 16/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2455 - accuracy: 0.9020
# Epoch 17/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2407 - accuracy: 0.9012
# Epoch 18/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2369 - accuracy: 0.9067
# Epoch 19/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2354 - accuracy: 0.9087
# Epoch 20/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2291 - accuracy: 0.9119
# Epoch 21/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2314 - accuracy: 0.9047
# Epoch 22/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2248 - accuracy: 0.9116
# Epoch 23/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2257 - accuracy: 0.9112
# Epoch 24/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2207 - accuracy: 0.9163
# Epoch 25/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2190 - accuracy: 0.9141
# Epoch 26/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2157 - accuracy: 0.9160
# Epoch 27/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2122 - accuracy: 0.9177
# Epoch 28/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2109 - accuracy: 0.9201
# Epoch 29/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.2104 - accuracy: 0.9201
# Epoch 30/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2020 - accuracy: 0.9233
# Epoch 31/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2010 - accuracy: 0.9258
# Epoch 32/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.1959 - accuracy: 0.9257
# Epoch 33/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.1966 - accuracy: 0.9293
# Epoch 34/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1937 - accuracy: 0.9295
# Epoch 35/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1887 - accuracy: 0.9304
# Epoch 36/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1888 - accuracy: 0.9307
# Epoch 37/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1851 - accuracy: 0.9338
# Epoch 38/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1825 - accuracy: 0.9329
# Epoch 39/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1822 - accuracy: 0.9339
# Epoch 40/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1816 - accuracy: 0.9356
# Epoch 41/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1781 - accuracy: 0.9361
# Epoch 42/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1795 - accuracy: 0.9356
# Epoch 43/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1757 - accuracy: 0.9371
# Epoch 44/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1715 - accuracy: 0.9367
# Epoch 45/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1704 - accuracy: 0.9417
# Epoch 46/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1682 - accuracy: 0.9410
# Epoch 47/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1668 - accuracy: 0.9424
# Epoch 48/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1649 - accuracy: 0.9435
# Epoch 49/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1603 - accuracy: 0.9462
# Epoch 50/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1603 - accuracy: 0.9450
# Epoch 51/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.1643 - accuracy: 0.9392
# Epoch 52/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.1593 - accuracy: 0.9449
# Epoch 53/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.1576 - accuracy: 0.9465
# Epoch 54/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.1554 - accuracy: 0.9454
# Epoch 55/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1545 - accuracy: 0.9444
# Epoch 56/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1535 - accuracy: 0.9479
# Epoch 57/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1515 - accuracy: 0.9476
# Epoch 58/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1493 - accuracy: 0.9499
# Epoch 59/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1475 - accuracy: 0.9497
# Epoch 60/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1465 - accuracy: 0.9499
# Epoch 61/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1455 - accuracy: 0.9501
# Epoch 62/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1427 - accuracy: 0.9518
# Epoch 63/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1442 - accuracy: 0.9488
# Epoch 64/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1417 - accuracy: 0.9513
# Epoch 65/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1408 - accuracy: 0.9529
# Epoch 66/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1368 - accuracy: 0.9544
# Epoch 67/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1363 - accuracy: 0.9540
# Epoch 68/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1373 - accuracy: 0.9537
# Epoch 69/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1339 - accuracy: 0.9550
# Epoch 70/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1328 - accuracy: 0.9552
# Epoch 71/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1295 - accuracy: 0.9562
# Epoch 72/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1302 - accuracy: 0.9588
# Epoch 73/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.1313 - accuracy: 0.9554
# Epoch 74/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.1285 - accuracy: 0.9575
# Epoch 75/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.1263 - accuracy: 0.9597
# Epoch 76/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1286 - accuracy: 0.9566
# Epoch 77/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1259 - accuracy: 0.9615
# Epoch 78/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1241 - accuracy: 0.9585
# Epoch 79/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1235 - accuracy: 0.9597
# Epoch 80/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1223 - accuracy: 0.9590
# Epoch 81/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1200 - accuracy: 0.9617
# Epoch 82/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1213 - accuracy: 0.9596
# Epoch 83/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1191 - accuracy: 0.9617
# Epoch 84/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1179 - accuracy: 0.9603
# Epoch 85/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1187 - accuracy: 0.9620
# Epoch 86/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1180 - accuracy: 0.9598
# Epoch 87/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1145 - accuracy: 0.9631
# Epoch 88/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1154 - accuracy: 0.9622
# Epoch 89/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1117 - accuracy: 0.9642
# Epoch 90/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1121 - accuracy: 0.9641
# Epoch 91/200
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1145 - accuracy: 0.9598
# Epoch 92/200
# 289/289 [==============================] - 2s 5ms/step - loss: 0.1091 - accuracy: 0.9659
# Epoch 93/200
# 289/289 [==============================] - 2s 6ms/step - loss: 0.1092 - accuracy: 0.9656
# Epoch 94/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1112 - accuracy: 0.9641
# Epoch 95/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1120 - accuracy: 0.9640
# Epoch 96/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1054 - accuracy: 0.9658
# Epoch 97/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1057 - accuracy: 0.9655
# Epoch 98/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1107 - accuracy: 0.9622
# Epoch 99/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1062 - accuracy: 0.9663
# Epoch 100/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1053 - accuracy: 0.9645
# Epoch 101/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1026 - accuracy: 0.9673
# Epoch 102/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1001 - accuracy: 0.9685
# Epoch 103/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1021 - accuracy: 0.9683
# Epoch 104/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1004 - accuracy: 0.9675
# Epoch 105/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1007 - accuracy: 0.9694
# Epoch 106/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1001 - accuracy: 0.9679
# Epoch 107/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.1015 - accuracy: 0.9659
# Epoch 108/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0966 - accuracy: 0.9689
# Epoch 109/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0950 - accuracy: 0.9716
# Epoch 110/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0973 - accuracy: 0.9701
# Epoch 111/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0964 - accuracy: 0.9688
# Epoch 112/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0988 - accuracy: 0.9683
# Epoch 113/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0947 - accuracy: 0.9697
# Epoch 114/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0946 - accuracy: 0.9672
# Epoch 115/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0918 - accuracy: 0.9698
# Epoch 116/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0939 - accuracy: 0.9703
# Epoch 117/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0925 - accuracy: 0.9703
# Epoch 118/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0926 - accuracy: 0.9703
# Epoch 119/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0912 - accuracy: 0.9715
# Epoch 120/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0893 - accuracy: 0.9720
# Epoch 121/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0892 - accuracy: 0.9714
# Epoch 122/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0903 - accuracy: 0.9704
# Epoch 123/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0876 - accuracy: 0.9733
# Epoch 124/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0856 - accuracy: 0.9740
# Epoch 125/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0857 - accuracy: 0.9745
# Epoch 126/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0860 - accuracy: 0.9726
# Epoch 127/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0833 - accuracy: 0.9746
# Epoch 128/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0857 - accuracy: 0.9733
# Epoch 129/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0860 - accuracy: 0.9740
# Epoch 130/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0847 - accuracy: 0.9737
# Epoch 131/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0851 - accuracy: 0.9739
# Epoch 132/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0835 - accuracy: 0.9730
# Epoch 133/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0816 - accuracy: 0.9753
# Epoch 134/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0790 - accuracy: 0.9751
# Epoch 135/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0815 - accuracy: 0.9741
# Epoch 136/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0774 - accuracy: 0.9767
# Epoch 137/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0791 - accuracy: 0.9748
# Epoch 138/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0797 - accuracy: 0.9754
# Epoch 139/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0807 - accuracy: 0.9736
# Epoch 140/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0775 - accuracy: 0.9773
# Epoch 141/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0758 - accuracy: 0.9779
# Epoch 142/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0760 - accuracy: 0.9752
# Epoch 143/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0766 - accuracy: 0.9768
# Epoch 144/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0763 - accuracy: 0.9761
# Epoch 145/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0757 - accuracy: 0.9771
# Epoch 146/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0728 - accuracy: 0.9778
# Epoch 147/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0771 - accuracy: 0.9767
# Epoch 148/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0749 - accuracy: 0.9762
# Epoch 149/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0738 - accuracy: 0.9763
# Epoch 150/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0746 - accuracy: 0.9775
# Epoch 151/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0732 - accuracy: 0.9773
# Epoch 152/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0741 - accuracy: 0.9772
# Epoch 153/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0747 - accuracy: 0.9759
# Epoch 154/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0736 - accuracy: 0.9763
# Epoch 155/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0705 - accuracy: 0.9792
# Epoch 156/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0702 - accuracy: 0.9779
# Epoch 157/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0681 - accuracy: 0.9798
# Epoch 158/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0671 - accuracy: 0.9786
# Epoch 159/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0704 - accuracy: 0.9785
# Epoch 160/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0715 - accuracy: 0.9780
# Epoch 161/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0677 - accuracy: 0.9780
# Epoch 162/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0680 - accuracy: 0.9809
# Epoch 163/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0685 - accuracy: 0.9769
# Epoch 164/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0679 - accuracy: 0.9802
# Epoch 165/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0668 - accuracy: 0.9800
# Epoch 166/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0653 - accuracy: 0.9804
# Epoch 167/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0634 - accuracy: 0.9819
# Epoch 168/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0636 - accuracy: 0.9812
# Epoch 169/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0662 - accuracy: 0.9795
# Epoch 170/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0639 - accuracy: 0.9809
# Epoch 171/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0637 - accuracy: 0.9817
# Epoch 172/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0618 - accuracy: 0.9824
# Epoch 173/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0633 - accuracy: 0.9805
# Epoch 174/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0623 - accuracy: 0.9813
# Epoch 175/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0625 - accuracy: 0.9803
# Epoch 176/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0649 - accuracy: 0.9796
# Epoch 177/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0597 - accuracy: 0.9824
# Epoch 178/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0598 - accuracy: 0.9824
# Epoch 179/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0595 - accuracy: 0.9828
# Epoch 180/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0619 - accuracy: 0.9820
# Epoch 181/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0616 - accuracy: 0.9820
# Epoch 182/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0614 - accuracy: 0.9821
# Epoch 183/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0583 - accuracy: 0.9826
# Epoch 184/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0611 - accuracy: 0.9814
# Epoch 185/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0589 - accuracy: 0.9821
# Epoch 186/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0553 - accuracy: 0.9839
# Epoch 187/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0590 - accuracy: 0.9825
# Epoch 188/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0584 - accuracy: 0.9824
# Epoch 189/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0565 - accuracy: 0.9834
# Epoch 190/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0592 - accuracy: 0.9824
# Epoch 191/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0570 - accuracy: 0.9824
# Epoch 192/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0587 - accuracy: 0.9817
# Epoch 193/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0580 - accuracy: 0.9817
# Epoch 194/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0558 - accuracy: 0.9839
# Epoch 195/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0557 - accuracy: 0.9831
# Epoch 196/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0592 - accuracy: 0.9822
# Epoch 197/200
# 289/289 [==============================] - 1s 3ms/step - loss: 0.0564 - accuracy: 0.9837
# Epoch 198/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0553 - accuracy: 0.9839
# Epoch 199/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0536 - accuracy: 0.9846
# Epoch 200/200
# 289/289 [==============================] - 1s 2ms/step - loss: 0.0524 - accuracy: 0.9847

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
def predict(model,x):
    pred  = model.predict(x)
    pred[pred >= 0.5] = 1
    pred[pred < 0.5] = 0
    return pred

def predict_graph(y_true,y_pred,title):
    cm = confusion_matrix(y_true,y_pred)
    plt.figure(figsize=(7,7))
    sns.heatmap(cm,annot=True,fmt='g',cmap="YlGnBu",
                xticklabels=['No Bankruptcy','Bankruptcy'],yticklabels=['No Bankruptcy','Bankruptcy'])
    plt.title(title)
    plt.show()

    print("\n")
    print("Classification Report:")
    print(classification_report(y_true,y_pred))

# %%
# Train set prediction
y_train_pred = predict(model,x_train)
predict_graph(y_train,y_train_pred,'Train Data Predictions')
# Out:
# 289/289 [==============================] - 2s 5ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98      4635
#            1       0.97      1.00      0.98      4603
#
#     accuracy                           0.98      9238
#    macro avg       0.98      0.98      0.98      9238
# weighted avg       0.98      0.98      0.98      9238

# %%
# Test Set prediction
y_test_pred = predict(model,x_test)
predict_graph(y_test,y_test_pred,'Test Data Predictions')
# Out:
# 124/124 [==============================] - 0s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97      1964
#            1       0.94      1.00      0.97      1996
#
#     accuracy                           0.97      3960
#    macro avg       0.97      0.97      0.97      3960
# weighted avg       0.97      0.97      0.97      3960
